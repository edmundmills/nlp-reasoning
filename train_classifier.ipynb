# %%
# %%capture
# !pip install transformers
# !pip install wandb

# %%
from google.colab import drive
drive.mount('/content/gdrive/')

# %%
import wandb
wandb.login()

# %%
# %cd /content/gdrive/MyDrive/nlp-reasoning

# %%
# !wandb login --relogin

# %%
# !python train_classifier.py
